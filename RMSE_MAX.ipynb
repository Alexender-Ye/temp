# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from collections.abc import Iterable

# %% [markdown]
# # Utils Function

# %%
def normalize_feature(x,axis=0):
    mu = np.mean(x, axis, keepdims=True)
    sigma = np.std(x, axis, keepdims=True)
    return (x-mu)/sigma

# %% [markdown]
# # Build Dataset

# %%
df = pd.read_csv("train_advance.csv",encoding='utf-8',sep=',')
df.shape
# Out:
# (22924, 31)

# %%
class InsDataset(Dataset):
    """Students Performance dataset."""

    def __init__(self, df):
        # get all useful numeric column
        dataset = df[['Unnamed: 0.1','Unnamed: 0','number_comments','following','followers','n_posts','numbr_likes']]

        # remove rows with NAN
        dataset = dataset.dropna(axis=0,how='all')

        dataset = dataset[dataset['following'].str.isdigit()]
        dataset['following'] = dataset['following'].apply(pd.to_numeric)

        # convert to numpy array
        dataset = dataset.values
        
        x = dataset[:,:6]
        y = dataset[:,6]
        
        # Save target and predictors        
        x = normalize_feature(x)
        self.x = torch.from_numpy(x).float()
        self.y = torch.from_numpy(y).float()

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        # Convert idx from tensor to list due to pandas bug (that arises when using pytorch's random_split)
        if isinstance(idx, torch.Tensor):
            idx = idx.tolist()

        return [self.x[idx], self.y[idx]]

# %%
dataset = InsDataset(df)

# Split into training and test
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
trainset, testset = random_split(dataset, [train_size, test_size])

# Dataloaders
trainloader = DataLoader(trainset, batch_size=128, shuffle=True)
testloader = DataLoader(testset, batch_size=128, shuffle=False)

# Use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # MLP

# %%
class MLPregressior(nn.Module):
    def __init__(self):
        super(MLPregressior, self).__init__()
        self.hidden1 = nn.Linear(in_features=6, out_features=128, bias=True)
        self.hidden2 = nn.Linear(128, 256)
        self.hidden3 = nn.Linear(256, 64)
        self.predict = nn.Linear(64, 1)
        self.bn1 = nn.BatchNorm1d(128)
        self.bn2 = nn.BatchNorm1d(256)
        self.bn3 = nn.BatchNorm1d(64)
        
    def forward(self, x):
        x = F.gelu(self.bn1(self.hidden1(x))) 
#         x = nn.Dropout()(x)
        x = F.gelu(self.bn2(self.hidden2(x)))
#         x = nn.Dropout()(x)
        x = F.gelu(self.bn3(self.hidden3(x)))
#         x = nn.Dropout()(x)
        output = self.predict(x)
        return output[:, 0]

# %%
model = MLPregressior().to(device)

# %%
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = torch.sqrt(loss_fn(pred, y))

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss, current = loss.item(), batch * len(X)
    print(f"Train loss: {loss:>7f}")

# %%
def validate(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += torch.sqrt(loss_fn(pred, y))
    test_loss /= num_batches

    print(f"Valid loss: {test_loss:>8f} \n")

# %%
epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(trainloader, model, loss_fn, optimizer)
    validate(testloader, model, loss_fn)
    scheduler.step()
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train loss: 10887.375000
# Valid loss: 18356.144531
#
# Epoch 2
# -------------------------------
# Train loss: 5684.979980
# Valid loss: 17914.343750
#
# Epoch 3
# -------------------------------
# Train loss: 22272.724609
# Valid loss: 16856.742188
#
# Epoch 4
# -------------------------------
# Train loss: 6119.857422
# Valid loss: 17258.867188
#
# Epoch 5
# -------------------------------
# Train loss: 7786.192871
# Valid loss: 15556.566406
#
# Epoch 6
# -------------------------------
# Train loss: 4520.923340
# Valid loss: 13863.684570
#
# Epoch 7
# -------------------------------
# Train loss: 5374.885254
# Valid loss: 13002.815430
#
# Epoch 8
# -------------------------------
# Train loss: 4471.912109
# Valid loss: 15402.026367
#
# Epoch 9
# -------------------------------
# Train loss: 6153.890137
# Valid loss: 12657.201172
#
# Epoch 10
# -------------------------------
# Train loss: 18258.878906
# Valid loss: 16035.279297
#
# Epoch 11
# -------------------------------
# Train loss: 7790.268066
# Valid loss: 13824.699219
#
# Epoch 12
# -------------------------------
# Train loss: 6380.127930
# Valid loss: 13595.561523
#
# Epoch 13
# -------------------------------
# Train loss: 2138.628418
# Valid loss: 15466.515625
#
# Epoch 14
# -------------------------------
# Train loss: 11618.605469
# Valid loss: 11631.265625
#
# Epoch 15
# -------------------------------
# Train loss: 5104.035645
# Valid loss: 12251.335938
#
# Epoch 16
# -------------------------------
# Train loss: 13166.923828
# Valid loss: 12406.529297
#
# Epoch 17
# -------------------------------
# Train loss: 3289.794434
# Valid loss: 12079.704102
#
# Epoch 18
# -------------------------------
# Train loss: 77518.984375
# Valid loss: 13024.228516
#
# Epoch 19
# -------------------------------
# Train loss: 3617.399902
# Valid loss: 11993.134766
#
# Epoch 20
# -------------------------------
# Train loss: 6624.883789
# Valid loss: 12713.872070
#
# Epoch 21
# -------------------------------
# Train loss: 21049.355469
# Valid loss: 12640.223633
#
# Epoch 22
# -------------------------------
# Train loss: 3139.138916
# Valid loss: 11706.800781
#
# Epoch 23
# -------------------------------
# Train loss: 4521.156738
# Valid loss: 11509.111328
#
# Epoch 24
# -------------------------------
# Train loss: 4416.430176
# Valid loss: 10962.991211
#
# Epoch 25
# -------------------------------
# Train loss: 8577.995117
# Valid loss: 12217.235352
#
# Epoch 26
# -------------------------------
# Train loss: 4854.893066
# Valid loss: 13028.418945
#
# Epoch 27
# -------------------------------
# Train loss: 4625.394043
# Valid loss: 12513.206055
#
# Epoch 28
# -------------------------------
# Train loss: 7117.901367
# Valid loss: 12466.772461
#
# Epoch 29
# -------------------------------
# Train loss: 3590.328857
# Valid loss: 14497.598633
#
# Epoch 30
# -------------------------------
# Train loss: 5068.391602
# Valid loss: 14487.844727
#
# Epoch 31
# -------------------------------
# Train loss: 13489.529297
# Valid loss: 13247.958008
#
# Epoch 32
# -------------------------------
# Train loss: 4455.817871
# Valid loss: 11797.843750
#
# Epoch 33
# -------------------------------
# Train loss: 3728.260742
# Valid loss: 12078.633789
#
# Epoch 34
# -------------------------------
# Train loss: 6970.394043
# Valid loss: 11884.682617
#
# Epoch 35
# -------------------------------
# Train loss: 3634.685547
# Valid loss: 11421.905273
#
# Epoch 36
# -------------------------------
# Train loss: 4062.683105
# Valid loss: 11490.019531
#
# Epoch 37
# -------------------------------
# Train loss: 2719.678223
# Valid loss: 12214.937500
#
# Epoch 38
# -------------------------------
# Train loss: 3717.648438
# Valid loss: 13004.528320
#
# Epoch 39
# -------------------------------
# Train loss: 4714.354004
# Valid loss: 12404.597656
#
# Epoch 40
# -------------------------------
# Train loss: 13634.188477
# Valid loss: 12773.758789
#
# Epoch 41
# -------------------------------
# Train loss: 32423.636719
# Valid loss: 11661.337891
#
# Epoch 42
# -------------------------------
# Train loss: 13103.444336
# Valid loss: 11979.645508
#
# Epoch 43
# -------------------------------
# Train loss: 6923.148926
# Valid loss: 12393.483398
#
# Epoch 44
# -------------------------------
# Train loss: 5997.657227
# Valid loss: 11431.066406
#
# Epoch 45
# -------------------------------
# Train loss: 4482.395020
# Valid loss: 12429.360352
#
# Epoch 46
# -------------------------------
# Train loss: 6026.629395
# Valid loss: 12767.516602
#
# Epoch 47
# -------------------------------
# Train loss: 14153.647461
# Valid loss: 11832.300781
#
# Epoch 48
# -------------------------------
# Train loss: 5933.283691
# Valid loss: 12670.382812
#
# Epoch 49
# -------------------------------
# Train loss: 3916.326172
# Valid loss: 11589.434570
#
# Epoch 50
# -------------------------------
# Train loss: 5976.690918
# Valid loss: 12707.101562
#
# Epoch 51
# -------------------------------
# Train loss: 7376.425781
# Valid loss: 12385.441406
#
# Epoch 52
# -------------------------------
# Train loss: 15062.513672
# Valid loss: 12352.146484
#
# Epoch 53
# -------------------------------
# Train loss: 5696.296387
# Valid loss: 11950.514648
#
# Epoch 54
# -------------------------------
# Train loss: 5601.594727
# Valid loss: 12023.740234
#
# Epoch 55
# -------------------------------
# Train loss: 5502.631348
# Valid loss: 13126.342773
#
# Epoch 56
# -------------------------------
# Train loss: 7394.321289
# Valid loss: 12095.346680
#
# Epoch 57
# -------------------------------
# Train loss: 3656.412354
# Valid loss: 12772.184570
#
# Epoch 58
# -------------------------------
# Train loss: 83708.718750
# Valid loss: 13289.636719
#
# Epoch 59
# -------------------------------
# Train loss: 3838.688477
# Valid loss: 12348.941406
#
# Epoch 60
# -------------------------------
# Train loss: 4281.491211
# Valid loss: 12182.099609
#
# Epoch 61
# -------------------------------
# Train loss: 2359.683838
# Valid loss: 13038.115234
#
# Epoch 62
# -------------------------------
# Train loss: 4882.499512
# Valid loss: 11960.150391
#
# Epoch 63
# -------------------------------
# Train loss: 4354.584961
# Valid loss: 11967.493164
#
# Epoch 64
# -------------------------------
# Train loss: 3628.399902
# Valid loss: 11794.916992
#
# Epoch 65
# -------------------------------
# Train loss: 2495.491211
# Valid loss: 12571.047852
#
# Epoch 66
# -------------------------------
# Train loss: 3582.023193
# Valid loss: 12176.739258
#
# Epoch 67
# -------------------------------
# Train loss: 12795.790039
# Valid loss: 13512.982422
#
# Epoch 68
# -------------------------------
# Train loss: 4821.396484
# Valid loss: 12154.651367
#
# Epoch 69
# -------------------------------
# Train loss: 7495.940430
# Valid loss: 12598.801758
#
# Epoch 70
# -------------------------------
# Train loss: 12234.338867
# Valid loss: 12527.093750
#
# Epoch 71
# -------------------------------
# Train loss: 4802.209961
# Valid loss: 12830.952148
#
# Epoch 72
# -------------------------------
# Train loss: 3138.906006
# Valid loss: 12837.613281
#
# Epoch 73
# -------------------------------
# Train loss: 3439.757812
# Valid loss: 12424.515625
#
# Epoch 74
# -------------------------------
# Train loss: 7303.895508
# Valid loss: 11988.741211
#
# Epoch 75
# -------------------------------
# Train loss: 6531.823730
# Valid loss: 12729.600586
#
# Epoch 76
# -------------------------------
# Train loss: 5310.228516
# Valid loss: 13188.371094
#
# Epoch 77
# -------------------------------
# Train loss: 7030.795898
# Valid loss: 12402.723633
#
# Epoch 78
# -------------------------------
# Train loss: 3804.240723
# Valid loss: 12226.274414
#
# Epoch 79
# -------------------------------
# Train loss: 8175.033691
# Valid loss: 12853.832031
#
# Epoch 80
# -------------------------------
# Train loss: 8736.336914
# Valid loss: 12619.292969
#
# Epoch 81
# -------------------------------
# Train loss: 4462.175293
# Valid loss: 12470.282227
#
# Epoch 82
# -------------------------------
# Train loss: 2555.709229
# Valid loss: 12813.689453
#
# Epoch 83
# -------------------------------
# Train loss: 5422.827637
# Valid loss: 12533.246094
#
# Epoch 84
# -------------------------------
# Train loss: 7630.863281
# Valid loss: 12636.121094
#
# Epoch 85
# -------------------------------
# Train loss: 4332.620117
# Valid loss: 12734.903320
#
# Epoch 86
# -------------------------------
# Train loss: 2948.913818
# Valid loss: 11745.015625
#
# Epoch 87
# -------------------------------
# Train loss: 4982.655273
# Valid loss: 12306.817383
#
# Epoch 88
# -------------------------------
# Train loss: 3865.052490
# Valid loss: 11749.198242
#
# Epoch 89
# -------------------------------
# Train loss: 4153.845703
# Valid loss: 11975.702148
#
# Epoch 90
# -------------------------------
# Train loss: 3792.409424
# Valid loss: 11964.571289
#
# Epoch 91
# -------------------------------
# Train loss: 4146.991211
# Valid loss: 13758.085938
#
# Epoch 92
# -------------------------------
# Train loss: 17343.656250
# Valid loss: 12014.347656
#
# Epoch 93
# -------------------------------
# Train loss: 3863.460938
# Valid loss: 12303.448242
#
# Epoch 94
# -------------------------------
# Train loss: 4805.824707
# Valid loss: 12574.397461
#
# Epoch 95
# -------------------------------
# Train loss: 4289.432129
# Valid loss: 12416.461914
#
# Epoch 96
# -------------------------------
# Train loss: 4989.708008
# Valid loss: 12020.251953
#
# Epoch 97
# -------------------------------
# Train loss: 4067.555176
# Valid loss: 12256.989258
#
# Epoch 98
# -------------------------------
# Train loss: 9870.146484
# Valid loss: 12463.409180
#
# Epoch 99
# -------------------------------
# Train loss: 5084.926758
# Valid loss: 12147.635742
#
# Epoch 100
# -------------------------------
# Train loss: 10470.183594
# Valid loss: 11932.828125
#
# Done!

# %%
df_test = pd.read_csv("test_advance.csv",encoding='utf-8',sep=',')
df_test.shape
# Out:
# (5731, 32)

# %%
dataset = df_test[['Unnamed: 0.1','Unnamed: 0','number_comments','following','followers','n_posts']]

# remove rows with NAN
dataset = dataset.dropna(axis=0,how='all')

#     dataset = dataset[dataset['following'].str.isdigit()]
dataset['following'] = dataset['following'].apply(pd.to_numeric)

# convert to numpy array
dataset = dataset.values

#     print(dataset)

dataset = normalize_feature(dataset)
dataset = torch.from_numpy(dataset).float()

# Save target and predictors
x = dataset.to(device)

model.eval()
y = model(x)
y
# Out:
# tensor([ 7800.9351,  4196.2764,  5653.3633,  ...,  1309.9447,   657.8683,
#         18489.3867], device='cuda:0', grad_fn=<SelectBackward0>)
